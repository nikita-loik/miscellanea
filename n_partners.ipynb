# %%
import numpy as np
import networkx as nx
import matplotlib
from matplotlib import pyplot as plt
plt.style.use('fivethirtyeight')

import utility_functions as uf

# %load_ext autoreload
# %autoreload 2

# %%
population_size = 50
b_ratio = 0.1
max_partners = 10

# %%
population_graph = uf.simulate_population(
    population_size=population_size,
    b_ratio=b_ratio,
    max_partners=max_partners)
# Out:
# boys # 7
# girls # 43
# average # partners per boy: 4.14
# average # partners per girl: 0.67

# %%
uf.plot_population_graph(population_graph)
