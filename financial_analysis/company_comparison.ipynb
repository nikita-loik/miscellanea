# %%
import os, sys, inspect

import pandas as pd
import matplotlib as plt
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

working_dir = os.path.dirname(
    os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(working_dir)
sys.path.insert(0, parent_dir)

import utilities as u

# %%
peptidream_csv_path = 'peptidream_historical_data.csv'
ra_pharma_csv_path = 'ra_pharma_historical_data.csv'

ra_pharma_market_cap = 2.27  # in billions of USD
peptidream_market_cap = 619.48  # in billions of USD (but, may be JPY)

peptidream_df = u.get_historical_data(
        csv_path=peptidream_csv_path)
ra_pharma_df = u.get_historical_data(
        csv_path=ra_pharma_csv_path)

# %%
u.plot_historical_data(
        data_dfs = [peptidream_df, ra_pharma_df])
# Out:
# &lt;Figure size 864x576 with 1 Axes&gt;
