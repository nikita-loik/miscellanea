# %%
import numpy as np
import networkx as nx
import matplotlib
from matplotlib import pyplot as plt
plt.style.use('fivethirtyeight')

import utility_functions as uf

# %load_ext autoreload
# %autoreload 2

# %%
population_size = 50
b_ratio = 0.5
max_partners = 5

# %%
population_graph = uf.simulate_population(
    population_size=population_size,
    b_ratio=b_ratio,
    max_partners=max_partners)
# Out:
# boys # 28
# girls # 22
# average # partners per boy: 1.89
# average # partners per girl: 2.41

# %%
uf.plot_population_graph(population_graph)
